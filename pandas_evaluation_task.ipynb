# %% [markdown]
# # Perform the following analysis on the provided file "demo.csv".
#
#
# ## 1. Which month saw the highest joining of the employees
#
#    function name: max_joinings_month()
#
#    inputs: DataFrame
#
#    outputs: str
#
#
# ## 2. What is the mean salary is the state KS
#
#    function name: mean_ks_salary()
#
#    inputs: DataFrame
#
#    outputs: float
#
#
# ## 3. Which Region has highest mean salary
#
#    function name: max_mean_salary_region()
#
#    inputs: DataFrame
#
#    outputs: str
#
#
# ## 4. Which region has lowest mean salary
#
#    function name: min_mean_salary_region()
#
#    inputs: DataFrame
#
#    outputs: str
#
#
# ## 5. Which City has highest mean weight
#
#    function name: max_mean_weight_city()
#
#    inputs: DataFrame
#
#    outputs: str
#
#
# ## 6. What is the difference between mean salary of Doctors and Professors
#
#    function name: dr_prof_mean_salary_diff()
#
#    inputs: DataFrame
#
#    outputs: float
#
#
# ## 7. How many female use yahoo
#
#    function name: females_with_yahoo()
#
#    inputs: DataFrame
#
#    outputs: int
#
#
# ## 8. How many Doctors use gmail
#
#    function name: doctors_with_gmail()
#
#    inputs: DataFrame
#
#    outputs: int
#
#
# ## 9. What is the password of the youngest male
#
#    function name: youngest_male_password()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
import pandas as pd

# demo.csv
# file_path = "demo.csv"
# df = pd.read_csv(file_path)
# display(df)

# test.csv
file_path = "test1.csv"
test_df = pd.read_csv(file_path)
# display(test_df)

# %%
test_df
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# 0              shawna.buck@yahoo.com       Rosario Buck          Keisha Buck
# 1        nathaniel.burke@walmart.com      Derrick Burke         Phoebe Burke
# 2         elisabeth.foster@yahoo.com       Irwin Foster         Janie Foster
# 3         briana.lancaster@gmail.com  Jeffrey Lancaster     Shelby Lancaster
# 4           estella.potter@yahoo.com      Booker Potter       Katelyn Potter
# ..                               ...                ...                  ...
# 995              bonnie.baker@bp.com      Edwardo Baker        Pauline Baker
# 996          luke.turner@charter.net      Javier Turner        Nicole Turner
# 997           eva.holman@hotmail.com         Coy Holman         Haley Holman
# 998  maritza.christian@microsoft.com     Dion Christian  Stephanie Christian
# 999       phyllis.dudley@gmail.co.in      Jarrod Dudley       Latisha Dudley
#
#     Mother's Maiden Name  ...          SSN     Phone No.  Place Name  \
# 0              Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# 1                   Pugh  ...  550-99-9897  231-765-6923       Irons
# 2                Delaney  ...  215-91-0004  270-749-4774   Lexington
# 3                  Weiss  ...  534-71-1053  219-623-8216     Munster
# 4                   Pate  ...  644-29-6396  907-677-8486   Fairbanks
# ..                   ...  ...          ...           ...         ...
# 995             Robinson  ...  064-02-6162  262-696-9171   Mukwonago
# 996                Sykes  ...  056-02-8240  231-629-0498    Freeport
# 997                Boyle  ...  343-11-1935  209-912-6705     Turlock
# 998               Mooney  ...  336-11-5030  203-224-9056    Stamford
# 999               Wilcox  ...  101-02-6501  405-970-2341        Meno
#
#                    County         City State    Zip     Region    User Name  \
# 0                   Clark    Las Vegas    NV  89128    Midwest       swbuck
# 1                    Lake  Bloomington    MI  49644       West      nzburke
# 2                 Fayette    Lexington    KY  40501      South     ewfoster
# 3                    Lake      Munster    IN  46321       West  bclancaster
# 4    Fairbanks North Star    Fairbanks    AK  99709    Midwest     elpotter
# ..                    ...          ...   ...    ...        ...          ...
# 995              Waukesha    Mukwonago    WI  53149       West      bkbaker
# 996                 Barry     Freeport    MI  49325       West     lsturner
# 997            Stanislaus      Turlock    KS  95381    Midwest     esholman
# 998             Fairfield     Stamford    CT   6910  Northeast  mhchristian
# 999                 Major         Meno    OK  73760      South     phdudley
#
#             Password
# 0    ja8?k3BTF^]o@<&
# 1     tPA@4Wh9Ja$+Ln
# 2    5D.B4IGNkWJfG<~
# 3          I%?JDM;pW
# 4        j4jkEXfC&Rh
# ..               ...
# 995   a?Co:/r;nu_wTQ
# 996       7n5@64VC7|
# 997    DG<<<e}*WgD<U
# 998         Krs@#TnM
# 999     h6wt@400%&Uu
#
# [1000 rows x 37 columns]

# %%
df.head(4)
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name   County  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas    Clark
# 1                 Pugh  ...  550-99-9897  231-765-6923       Irons     Lake
# 2              Delaney  ...  215-91-0004  270-749-4774   Lexington  Fayette
# 3                Weiss  ...  534-71-1053  219-623-8216     Munster     Lake
#
#         City State    Zip   Region    User Name         Password
# 0  Las Vegas    NV  89128     West       swbuck  ja8?k3BTF^]o@<&
# 1      Irons    MI  49644  Midwest      nzburke   tPA@4Wh9Ja$+Ln
# 2  Lexington    KY  40501    South     ewfoster  5D.B4IGNkWJfG<~
# 3    Munster    IN  46321  Midwest  bclancaster        I%?JDM;pW
#
# [4 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# 25%            4.000000        9.000000                3.152500
# 50%            6.000000       17.000000                7.815000
# 75%           10.000000       24.000000               15.465000
# max           12.000000       31.000000               37.570000
#
#               Salary           Zip
# count    1000.000000   1000.000000
# mean   120288.528000  48698.499000
# std     45178.339916  27396.021481
# min     40040.000000   1002.000000
# 25%     82122.000000  25421.750000
# 50%    119409.000000  47416.500000
# 75%    159109.000000  71101.000000
# max    199943.000000  99791.000000

# %%
df[['Date of Joining', 'Quarter of Joining',
       'Half of Joining', 'Year of Joining', 'Month of Joining',
       'Month Name of Joining', 'Short Month', 'Day of Joining',
       'DOW of Joining', 'Short DOW',]]
# Out:
#     Date of Joining Quarter of Joining Half of Joining  Year of Joining  \
# 0        12/18/2010                 Q4              H2             2010
# 1         4/25/2017                 Q2              H1             2017
# 2         3/27/2017                 Q1              H1             2017
# 3         2/25/2003                 Q1              H1             2003
# 4        10/11/2016                 Q4              H2             2016
# ..              ...                ...             ...              ...
# 995        1/7/2008                 Q1              H1             2008
# 996        3/5/2010                 Q1              H1             2010
# 997       2/20/2001                 Q1              H1             2001
# 998       3/15/2012                 Q1              H1             2012
# 999       1/17/1980                 Q1              H1             1980
#
#      Month of Joining Month Name of Joining Short Month  Day of Joining  \
# 0                  12              December         Dec              18
# 1                   4                 April         Apr              25
# 2                   3                 March         Mar              27
# 3                   2              February         Feb              25
# 4                  10               October         Oct              11
# ..                ...                   ...         ...             ...
# 995                 1               January         Jan               7
# 996                 3                 March         Mar               5
# 997                 2              February         Feb              20
# 998                 3                 March         Mar              15
# 999                 1               January         Jan              17
#
#     DOW of Joining Short DOW
# 0         Saturday       Sat
# 1          Tuesday       Tue
# 2           Monday       Mon
# 3          Tuesday       Tue
# 4          Tuesday       Tue
# ..             ...       ...
# 995         Monday       Mon
# 996         Friday       Fri
# 997        Tuesday       Tue
# 998       Thursday       Thu
# 999       Thursday       Thu
#
# [1000 rows x 10 columns]

# %%
df['Date of Joining']
# Out:
# 0      12/18/2010
# 1       4/25/2017
# 2       3/27/2017
# 3       2/25/2003
# 4      10/11/2016
#           ...
# 995      1/7/2008
# 996      3/5/2010
# 997     2/20/2001
# 998     3/15/2012
# 999     1/17/1980
# Name: Date of Joining, Length: 1000, dtype: object

# %% [markdown]
# ## 1. Which month saw the highest joining of the employees
#
#    function name: max_joinings_month()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
df['Month of Joining'] = pd.to_datetime(df['Date of Joining']).dt.month
df[

# %%
def max_joinings_month(df):
    df['Month of Joining'] = pd.to_datetime(df['Date of Joining']).dt.month
    counts_of_joining = df['Month of Joining'].value_counts()
    max_month = counts_of_joining.idxmax()
    return max_month
    

print("on demo.csv",max_joinings_month(df))
print("on test.csv",max_joinings_month(test_df))
# Out:
# on demo.csv 4
# on test.csv 4

# %% [markdown]
# ## 2. What is the mean salary is the state KS
#
#    function name: mean_ks_salary()
#
#    inputs: DataFrame
#
#    outputs: float

# %%
def mean_ks_salary(df):
    KS_state=df[df['State']=='KS']
    mean_ks=KS_state['Salary'].mean()
    return mean_ks

print("on demo.csv",mean_ks_salary(df))
print("on test.csv",mean_ks_salary(test_df))
# Out:
# on demo.csv 104225.45454545454
# on test.csv 121682.33333333333

# %%
df['Region']
# Out:
# 0           West
# 1        Midwest
# 2          South
# 3        Midwest
# 4           West
#          ...
# 995      Midwest
# 996      Midwest
# 997         West
# 998    Northeast
# 999        South
# Name: Region, Length: 1000, dtype: object

# %%
d=df.groupby('Region')['Salary'].mean()
d
# Out:
# Region
# Midwest      122633.645614
# Northeast    118978.379121
# South        119731.595687
# West         118910.197531
# Name: Salary, dtype: float64

# %% [markdown]
# ## 3. Which Region has highest mean salary
#
#    function name: max_mean_salary_region()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
def max_mean_salary_region(df):
    df_region=df.groupby('Region')['Salary'].mean()
    return df_region.idxmax()

print("on demo.csv",max_mean_salary_region(df))
print("on test.csv",max_mean_salary_region(test_df))
# Out:
# on demo.csv Midwest
# on test.csv West

# %% [markdown]
# ## 4. Which region has lowest mean salary
#
#    function name: min_mean_salary_region()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
def min_mean_salary_region(df):
    df_region=df.groupby('Region')['Salary'].mean()
    return df_region.idxmin()
    

print("on demo.csv",min_mean_salary_region(df))
print("on test.csv",min_mean_salary_region(test_df))
# Out:
# on demo.csv West
# on test.csv Midwest

# %% [markdown]
# ## 5. Which City has highest mean weight
#
#    function name: max_mean_weight_city()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
def max_mean_weight_city(df):
    df_weight=df.groupby('City')['Weight in Kgs.'].mean()
    return df_weight.idxmax()

print("on demo.csv",max_mean_weight_city(df))
print("on test.csv",max_mean_weight_city(test_df))
# Out:
# on demo.csv Conroe
# on test.csv Conroe

# %% [markdown]
# ## 6. What is the difference between mean salary of Doctors and Professors
#
#    function name: dr_prof_mean_salary_diff()
#
#    inputs: DataFrame
#
#    outputs: float

# %%
def dr_prof_mean_salary_diff(df):
    dr_salary=df[(df['Name Prefix']=='Drs.') & (df['Name Prefix']=='Dr.')]
    Pr_salary=df[df['Name Prefix']=='Prof.']
    mean_salary_doctors = dr_salary['Salary'].mean()
    mean_salary_professors = Pr_salary['Salary'].mean()
    both_mean=mean_salary_doctors-mean_salary_professors
    return both_mean

print("on demo.csv",dr_prof_mean_salary_diff(df))
print("on test.csv",dr_prof_mean_salary_diff(test_df))
# Out:
# on demo.csv nan
# on test.csv nan

# %% [markdown]
# ## 7. How many female use yahoo
#
#    function name: females_with_yahoo()
#
#    inputs: DataFrame
#
#    outputs: int

# %%
df[['Gender', 'E Mail']]
# Out:
#     Gender                           E Mail
# 0        F            shawna.buck@gmail.com
# 1        M      nathaniel.burke@walmart.com
# 2        F       elisabeth.foster@gmail.com
# 3        F       briana.lancaster@yahoo.com
# 4        F         estella.potter@gmail.com
# ..     ...                              ...
# 995      F              bonnie.baker@bp.com
# 996      M          luke.turner@charter.net
# 997      F           eva.holman@hotmail.com
# 998      F  maritza.christian@microsoft.com
# 999      F       phyllis.dudley@yahoo.co.in
#
# [1000 rows x 2 columns]

# %%
def females_with_yahoo(df):
    df_f = df[(df['Gender'] == 'F') & df['E Mail'].str.endswith('@yahoo.com', na=False) | df['E Mail'].str.endswith('@yahoo.co.in', na=False)]
    
    # Count the number of female Yahoo users
    f_with_yahoo = len(df_f)

    return f_with_yahoo
    
    

print("on demo.csv",females_with_yahoo(df))
print("on test.csv",females_with_yahoo(test_df))
# Out:
# on demo.csv 61
# on test.csv 161

# %%
df_fa=df[(df['Gender']=='F') & (df['E Mail'].str.endswith('@gmail.com', na=True))]
df_fa
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 4    787549        Hon.    Estella              L     Potter      F
# 7    159108        Mrs.     Shanna              U      Silva      F
# 8    330816         Ms.    Jasmine              J    Freeman      F
# ..      ...         ...        ...            ...        ...    ...
# 961  964222        Mrs.      Alana              S  Henderson      F
# 964  498361        Mrs.      Elise              A  Zimmerman      F
# 973  174542         Ms.   Rochelle              R   Guerrero      F
# 974  857324        Drs.      Terra              Z       Webb      F
# 986  149818        Mrs.    Ophelia              Z       Pena      F
#
#                           E Mail     Father's Name         Mother's Name  \
# 0          shawna.buck@gmail.com      Rosario Buck           Keisha Buck
# 2     elisabeth.foster@gmail.com      Irwin Foster          Janie Foster
# 4       estella.potter@gmail.com     Booker Potter        Katelyn Potter
# 7         shanna.silva@gmail.com      Eliseo Silva          Minnie Silva
# 8      jasmine.freeman@gmail.com      Hans Freeman         Renee Freeman
# ..                           ...               ...                   ...
# 961    alana.henderson@gmail.com    Chad Henderson  Alexandria Henderson
# 964    elise.zimmerman@gmail.com   Abdul Zimmerman      Hester Zimmerman
# 973  rochelle.guerrero@gmail.com  Houston Guerrero       Louise Guerrero
# 974         terra.webb@gmail.com        Denis Webb           Marion Webb
# 986       ophelia.pena@gmail.com         Rick Pena          Dolores Pena
#
#     Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0              Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# 2                Delaney  ...  215-91-0004  270-749-4774   Lexington
# 4                   Pate  ...  644-29-6396  907-677-8486   Fairbanks
# 7               Callahan  ...  673-48-7003  236-373-6712     Herndon
# 8                Mcbride  ...  600-99-8437  423-796-1535       Ocoee
# ..                   ...  ...          ...           ...         ...
# 961               Snyder  ...  416-67-9779  701-366-9793        Erie
# 964             Reynolds  ...  322-11-8121  215-954-2885    Scranton
# 973               Carson  ...  120-98-6307  229-820-6585      Pooler
# 974                Boyer  ...  266-99-6589  216-696-0115  Youngstown
# 986               Romero  ...  144-23-2416  229-494-7152   Kingsland
#
#                    County        City State    Zip     Region    User Name  \
# 0                   Clark   Las Vegas    NV  89128       West       swbuck
# 2                 Fayette   Lexington    KY  40501      South     ewfoster
# 4    Fairbanks North Star   Fairbanks    AK  99709       West     elpotter
# 7                 Fairfax     Herndon    VA  20171      South      susilva
# 8                    Polk       Ocoee    TN  37361      South    jjfreeman
# ..                    ...         ...   ...    ...        ...          ...
# 961                  Cass        Erie    ND  58029    Midwest  ashenderson
# 964            Lackawanna    Scranton    PA  18501  Northeast  eazimmerman
# 973               Chatham      Pooler    GA  31322      South   rrguerrero
# 974              Mahoning  Youngstown    OH  44599    Midwest       tzwebb
# 986                Camden   Kingsland    GA  31548      South       ozpena
#
#             Password
# 0    ja8?k3BTF^]o@<&
# 2    5D.B4IGNkWJfG<~
# 4        j4jkEXfC&Rh
# 7    oudj2Bq4vc2_{PU
# 8      Q.8<Q>K*H\*6f
# ..               ...
# 961   AYWTL|Q%.kA$^&
# 964        zU7yzd-8l
# 973       hr{Bx8+HV6
# 974   pi%7:Wh<EPh%_+
# 986    LcvCCDt}:W58\
#
# [161 rows x 37 columns]

# %%
df[df['Name Prefix']=='Dr.']
# Out:
#      Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 13   966375         Dr.     Mathew              O     Hodge      M
# 15   673049         Dr.       Cole              E    Jensen      M
# 33   880704         Dr.   Benjamin              X  Jennings      M
# 45   415161         Dr.     Lemuel              V  Guerrero      M
# 55   238992         Dr.      Carlo              X    Albert      M
# ..      ...         ...        ...            ...       ...    ...
# 901  674436         Dr.     Lenard              R  Cardenas      M
# 909  452967         Dr.      Lyman              D    Reeves      M
# 912  884068         Dr.     Moises              V    Berger      M
# 987  352882         Dr.        Lon              P    Harper      M
# 994  172440         Dr.       Cody              H   Allison      M
#
#                           E Mail      Father's Name     Mother's Name  \
# 13      mathew.hodge@hotmail.com       Prince Hodge      Regina Hodge
# 15           cole.jensen@aol.com     Terence Jensen    Belinda Jensen
# 33   benjamin.jennings@gmail.com  Wilfredo Jennings     Toni Jennings
# 45       lemuel.guerrero@aol.com     Silas Guerrero  Cecelia Guerrero
# 55        carlo.albert@gmail.com      Sydney Albert    Clarice Albert
# ..                           ...                ...               ...
# 901  lenard.cardenas@yahoo.co.uk   Kenneth Cardenas     John Cardenas
# 909       lyman.reeves@yahoo.com       Myles Reeves      Shari Reeves
# 912      moises.berger@shell.com        Lynn Berger      Pearl Berger
# 987           lon.harper@aol.com        Abel Harper   Isabella Harper
# 994       cody.allison@gmail.com    Sheldon Allison   Rachael Allison
#
#     Mother's Maiden Name  ...          SSN    Phone No.        Place Name  \
# 13             Henderson  ...  161-86-9547  209-294-7430         Van Nuys
# 15                 Brown  ...  762-12-1934  405-495-4201    Oklahoma City
# 33                 Silva  ...  585-99-8326  907-621-7774         Shungnak
# 45                Hinton  ...  759-12-8112  215-226-4111           Listie
# 55                Hebert  ...  684-24-8918  212-267-9103        Liverpool
# ..                   ...  ...          ...           ...              ...
# 901               Snyder  ...  118-98-3789  252-633-3990           Bahama
# 909                Potts  ...  261-99-5615  207-961-9872         Fryeburg
# 912                Smith  ...  472-57-1193  209-999-1866    San Francisco
# 987              Kennedy  ...  655-36-7746  316-912-3105  Shawnee Mission
# 994           Harrington  ...  312-35-7906  209-221-5075         Pasadena
#
#                County             City State    Zip     Region   User Name  \
# 13        Los Angeles         Van Nuys    CA  91404       West     mohodge
# 15           Oklahoma    Oklahoma City    OK  73184      South    cejensen
# 33   Northwest Arctic         Shungnak    AK  99773       West  bxjennings
# 45           Somerset           Listie    PA  15549  Northeast  lvguerrero
# 55           Onondaga        Liverpool    NY  13088  Northeast    cxalbert
# ..                ...              ...   ...    ...        ...         ...
# 901            Durham           Bahama    NC  27503      South  lrcardenas
# 909            Oxford         Fryeburg    ME   4037  Northeast    ldreeves
# 912     San Francisco    San Francisco    CA  94141       West    mvberger
# 987           Johnson  Shawnee Mission    KS  66201    Midwest    lpharper
# 994       Los Angeles         Pasadena    CA  91051       West   challison
#
#            Password
# 13   1E7oKc:M!cKsgq
# 15   C@#*|0ODx{7%bc
# 33   4u:O$kyhzQD32$
# 45       kB1pj3NT#{
# 55      zL^Du$>q+nG
# ..              ...
# 901     p*6t:Hg1e#u
# 909        b*#_noE^
# 912        BN~+*KA]
# 987   Rd9Kee@jTzB.a
# 994  CH_;sWI#:j8p4I
#
# [64 rows x 37 columns]

# %% [markdown]
# ## 8. How many Doctors use gmail
#
#    function name: doctors_with_gmail()
#
#    inputs: DataFrame
#
#    outputs: int

# %%
def doctors_with_gmail(df):
    df_f = df[((df['Name Prefix'] == 'Dr.')) | ((df['Name Prefix'] == 'Drs.')) & df['E Mail'].str.endswith('@gmail.com', na=False)]
    
    # Count the number of female Yahoo users
    f_with_gmail = len(df_f)

    return f_with_gmail

print("on demo.csv",doctors_with_gmail(df))
print("on test.csv",doctors_with_gmail(test_df))
# Out:
# on demo.csv 84
# on test.csv 59

# %% [markdown]
# ## 9. What is the password of the youngest male
#
#    function name: youngest_male_password()
#
#    inputs: DataFrame
#
#    outputs: str

# %%
def youngest_male_password(df):
    male_df = df[df['Gender'] == 'Male']
    min_age=male_df['Age'].idxmin()
    

print("on demo.csv",youngest_male_password(df))
print("on test.csv",youngest_male_password(test_df))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 6
#       2     male_df = df[df['Gender'] == 'Male']
#       3     min_age=male_df['Age'].idxmin()
# ----> 6 print("on demo.csv",youngest_male_password(df))
#       7 print("on test.csv",youngest_male_password(test_df))
#
# Cell In[93], line 3, in youngest_male_password(df)
#       1 def youngest_male_password(df):
#       2     male_df = df[df['Gender'] == 'Male']
# ----> 3     min_age=male_df['Age'].idxmin()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Age'
