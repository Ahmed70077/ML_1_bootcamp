---------------------------------------- 0.0/50.3 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.3 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/50.3 kB 217.9 kB/s eta 0:00:01
#      ----------------------- -------------- 30.7/50.3 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 50.3/50.3 kB 320.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Twisted in c:\users\hp\anaconda3\lib\site-packages (from tensor) (22.10.0)
# Requirement already satisfied: PyYaml in c:\users\hp\anaconda3\lib\site-packages (from tensor) (6.0)
# Requirement already satisfied: protobuf in c:\users\hp\anaconda3\lib\site-packages (from tensor) (4.23.4)
# Collecting construct (from tensor)
#   Obtaining dependency information for construct from https://files.pythonhosted.org/packages/b2/fb/08b3f4bf05da99aba8ffea52a558758def16e8516bc75ca94ff73587e7d3/construct-2.10.70-py3-none-any.whl.metadata
#   Downloading construct-2.10.70-py3-none-any.whl.metadata (4.2 kB)
# Collecting pysnmp (from tensor)
#   Downloading pysnmp-4.4.12-py2.py3-none-any.whl (296 kB)
#      ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#      -------- ------------------------------ 61.4/296.5 kB 1.1 MB/s eta 0:00:01
#      ------------------- ------------------ 153.6/296.5 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ - 286.7/296.5 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 296.5/296.5 kB 2.0 MB/s eta 0:00:00
# Collecting pysmi (from pysnmp->tensor)
#   Downloading pysmi-0.3.4-py2.py3-none-any.whl (80 kB)
#      ---------------------------------------- 0.0/80.0 kB ? eta -:--:--
#      ---------------------------------------- 80.0/80.0 kB 4.4 MB/s eta 0:00:00
# Collecting pycryptodomex (from pysnmp->tensor)
#   Obtaining dependency information for pycryptodomex from https://files.pythonhosted.org/packages/3c/a4/81675804055339db8e277f48bf0012b554a2322f15d000caebf7c8d3f011/pycryptodomex-3.19.0-cp35-abi3-win_amd64.whl.metadata
#   Downloading pycryptodomex-3.19.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyasn1>=0.2.3 in c:\users\hp\anaconda3\lib\site-packages (from pysnmp->tensor) (0.4.8)
# Requirement already satisfied: zope.interface>=4.4.2 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (5.4.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (21.0.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (22.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (4.7.1)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\hp\anaconda3\lib\site-packages (from Twisted->tensor) (1.0.2)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from Automat>=0.8.0->Twisted->tensor) (1.16.0)
# Requirement already satisfied: idna>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from hyperlink>=17.1.1->Twisted->tensor) (3.4)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from zope.interface>=4.4.2->Twisted->tensor) (68.0.0)
# Requirement already satisfied: ply in c:\users\hp\anaconda3\lib\site-packages (from pysmi->pysnmp->tensor) (3.11)
# Downloading construct-2.10.70-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.0 kB ? eta -:--:--
#    ---------------------------------------- 63.0/63.0 kB 1.7 MB/s eta 0:00:00
# Downloading pycryptodomex-3.19.0-cp35-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/1.7 MB 4.6 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.7 MB 3.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.7 MB 3.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.7 MB 3.7 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.7 MB 3.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.7 MB 3.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.2/1.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.7 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.3 MB/s eta 0:00:00
# Building wheels for collected packages: tensor
#   Building wheel for tensor (setup.py): started
#   Building wheel for tensor (setup.py): finished with status 'done'
#   Created wheel for tensor: filename=tensor-0.3.6-py3-none-any.whl size=71559 sha256=6f90462bae8e239f72a2bff767e126312819859546d4353a9b744587e0b62e97
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d9\71\a7\060c2d3ffc42a12287181a642b48a18699f76199693f835719
# Successfully built tensor
# Installing collected packages: pysmi, pycryptodomex, construct, pysnmp, tensor
# Successfully installed construct-2.10.70 pycryptodomex-3.19.0 pysmi-0.3.4 pysnmp-4.4.12 tensor-0.3.6

# %%
import keras
import random
import collections
import numpy as np
import matplotlib.pyplot as plt

import tensorflow
def display_random_images_with_labels(d, n=10):
    """
        accept dataset in tuple form, first index
        is np arrays (images) and second is labels
        and display n random images with labels
        from it
        Inputs:
            d (tuple): dataset images, dataset labels on same indexs
            n (int): number of samples to display (default: 10)
        Output:
            None
    """
    choices = list(range(len(d[0])))
    for i in range(n):
        index = random.choice(choices)
        choices.remove(index)
        print("index:",index)
        print("Lable:",d[1][index])
        plt.imshow(d[0][index], cmap='gray')
        plt.show()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_1084\3103575106.py", line 1, in <module>
#     import keras
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\__init__.py", line 3, in <module>
#     from keras import __internal__
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\__internal__\__init__.py", line 6, in <module>
#     from keras.__internal__ import models
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\__internal__\models\__init__.py", line 3, in <module>
#     from keras.src.models.cloning import clone_and_build_model
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\src\__init__.py", line 21, in <module>
#     from keras.src import applications
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\src\applications\__init__.py", line 41, in <module>
#     from keras.src.applications.inception_resnet_v2 import InceptionResNetV2
#   File "C:\Users\HP\anaconda3\Lib\site-packages\keras\src\applications\inception_resnet_v2.py", line 324, in <module>
#     @keras.utils.register_keras_serializable()
#      ^^^^^^^^^^^
# AttributeError: partially initialized module 'keras.src' has no attribute 'utils' (most likely due to a circular import)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\HP\anaconda3\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# Loading dataset
dataset = tensorflow.keras.datasets.mnist.load_data()

# Description of dataset

# mnint is handwritten digits (0 to 9) images dataset
# keras.datasets.mnist.load_data() loads those images in gray scale as cv2 images / np arrays
# with those labels


# dataset is in tuple form,
# its first index dataset[0] represents training dataset
# its second index dataset[1] represents testing dataset

# Both training (dataset[0]) and testing (dataset[1]) datasets
# are further tuples and have two elements,

# first element of both training and testing (dataset[0][0] and dataset[0][0])
# represnts images in numpy arrays
print("There are",len(dataset[0][0]),"images in training dataset")
print("There are",len(dataset[1][0]),"images in training dataset")
print("___________________\n\n")
# Each image is of shape 28x28
# print(dataset[0][0][0].shape)
# print("___________________")


# second element of both training and testing (dataset[0][1] and dataset[0][1])
# represnts labels of the images, presents on the same index in images
# For example dataset[0][0][0] is an image in training dataset
# and dataset[0][1][0] is the label of same image is training dataset
print("Randomly printing 10 images with labels from training dataset")
display_random_images_with_labels(dataset[0])
print("___________________\n\n")
print("Randomly printing 10 images with labels from testing dataset")
display_random_images_with_labels(dataset[0])
print("___________________\n\n")

print("There are",len(dataset[0][1]),"labels in training dataset for",len(dataset[0][0]),"images in training dataset")
print("There are",len(dataset[1][1]),"labels in training dataset for",len(dataset[1][0]),"images in training dataset")
print("___________________\n\n")

print("There are", len(set(dataset[0][1])),"unique classes in training dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[0][1]))
print("There are", len(set(dataset[1][1])),"unique classes in validation dataset")
print("Breakdown of each labels is below (format: dict key is label, dict value is occurrence of that label/ number of images for that label)")
display(collections.Counter(dataset[1][1]))
print("___________________\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Loading dataset
# ----> 2 dataset = tensorflow.keras.datasets.mnist.load_data()
#       4 # Description of dataset
#       5
#       6 # mnint is handwritten digits (0 to 9) images dataset
#    (...)
#      18 # first element of both training and testing (dataset[0][0] and dataset[0][0])
#      19 # represnts images in numpy arrays
#      20 print("There are",len(dataset[0][0]),"images in training dataset")
#
# NameError: name 'tensorflow' is not defined
