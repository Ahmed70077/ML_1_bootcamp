# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("img.jpeg")

# %%
img.shape
# Out:
# (440, 631, 3)

# %% [markdown]
# ## Grayscale

# %%
img_gray=cv2.imread('img,jpeg',0)

# %% [markdown]
# ## Flip image 360o

# %%
import numpy as np
directory_path = r'F:\img360'
if img is None:
    print("Error: Unable to load the image.")
else:

    height, width, _ = img.shape

    # Flip the image in every angle (360 degrees)
    for angle in range(0, 360, 1):
        # Rotate the image by the current angle
        rotated_image = cv2.warpAffine(img, cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1), (width, height))

        # Display the rotated image
        cv2.imshow('Rotated Image', rotated_image)
        cv2.waitKey(10)  # Adjust the waitKey delay as needed

        # Save the rotated image to a file
        save_path = f'{directory_path}\\image_{angle}.jpg'
        cv2.imwrite(save_path, rotated_image)

    cv2.destroyAllWindows()

# %%
blur = cv2.GaussianBlur(img, (35,35),0)
save_path = f'{directory_path}\\image_blur.jpg'
cv2.imwrite(save_path,blur)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
img_1=img+np.array([100])
brightened_image = np.clip(img_1, 0, 255).astype(np.uint8)
plt.imshow(cv2.cvtColor(brightened_image, cv2.COLOR_BGR2RGB))
plt.title('Brightened Image')
# Out:
# Text(0.5, 1.0, 'Brightened Image')

# %% [markdown]
# ## Rectangle

# %%
img_2=cv2.rectangle(img,(90,130),(500,300),(0,0,255), 3)
plt.imshow(cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB))
plt.title('Rectangle Image')
# Out:
# Text(0.5, 1.0, 'Rectangle Image')

# %%
car=cv2.imread('car.jpg')
plt.imshow(cv2.cvtColor(car, cv2.COLOR_BGR2RGB))
plt.title('car')
# Out:
# Text(0.5, 1.0, 'car')

# %%
car.shape
# Out:
# (1833, 3259, 3)

# %%
img_3=cv2.rectangle(car,(380,300),(2800,1500),(0,0,255), 3)
plt.imshow(cv2.cvtColor(img_3, cv2.COLOR_BGR2RGB))
plt.title('Rectangle Image')
# Out:
# Text(0.5, 1.0, 'Rectangle Image')
