# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
circle=cv2.imread('abc.png')
plt.imshow(cv2.cvtColor(circle, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
cir=circle[10:170,20:220]
plt.imshow(cv2.cvtColor(cir, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
circle.shape
# Out:
# (190, 265, 3)

# %%
hsv = cv2.cvtColor(circle, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(cv2.cvtColor(hsv, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
lower_red = np.array([0, 50, 50])
upper_red = np.array([10, 255, 255])
mask = cv2.inRange(hsv, lower_red, upper_red)
circle[mask>1] = [0, 0, 0]

# %%
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))
plt.title('Mask Image')
# Out:
# Text(0.5, 1.0, 'Mask Image')

# %%
plt.imshow(cv2.cvtColor(circle, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
sig=cv2.imread('C:\\Users\\HP\\Downloads\\Handsign\\NFI-00101001.png')
plt.imshow(cv2.cvtColor(sig, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
hsv = cv2.cvtColor(sig, cv2.COLOR_BGR2HSV)
plt.imshow(cv2.cvtColor(hsv, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
lower_red = np.array([0, 50, 50])
upper_red = np.array([10, 255, 255])
mask = cv2.inRange(hsv, lower_red, upper_red)
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
card=sig=cv2.imread('idcard.jpg')
plt.imshow(cv2.cvtColor(card, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
card.shape
# Out:
# (316, 500, 3)

# %%
card_ind=card[220:295,350:470]
plt.imshow(cv2.cvtColor(card_ind, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
sig_1=cv2.imread('1.png')

# %%
image = cv2.resize(sig_1, (113, 43))
hsv = cv2.cvtColor(sig_1, cv2.COLOR_BGR2HSV)
lower_black_gray = np.array([0, 0, 0])
upper_black_gray = np.array([180, 255, 100])
black_gray_mask = cv2.inRange(hsv, lower_black_gray, upper_black_gray)
plt.imshow(cv2.cvtColor(black_gray_mask, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')   # Load the second image
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
left_upper = (367, 235)
right_bottom = (480, 278)
roi = card[left_upper[1]:right_bottom[1], left_upper[0]:right_bottom[0]]
plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
# Text(0.5, 1.0, 'Orignal Image')

# %%
plt.imshow(cv2.cvtColor(roi[mask!0]=[0,0,0], cv2.COLOR_BGR2RGB))
plt.title('Orignal Image')
# Out:
#   Cell In[4], line 1
#     plt.imshow(cv2.cvtColor(roi[mask!0]=[0,0,0], cv2.COLOR_BGR2RGB))
#                                     ^
# SyntaxError: invalid syntax

# %%
def process_image(image1_path, image2_path):
    # Load the first image
    image = cv2.imread(image1_path)
    # Resize the image to 113x43
    image = cv2.resize(image, (113, 43))
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_black = np.array([0, 0, 0])
    upper_black = np.array([180, 255, 100])
    mask = cv2.inRange(hsv, lower_black_gray, upper_black_gray)
    # Load the second image
    image_2 = cv2.imread(image2_path)
    # Extract the roi from second image
    left_upper = (367, 235)
    right_bottom = (480, 278)
    roi = image_2[left_upper[1]:right_bottom[1], left_upper[0]:right_bottom[0]]
    roi[mask != 0] = [0, 0, 0]
    return image_2

# %%
for filename in os.listdir(image_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png', '.bmp')):
        # Read the image
        image1_path = os.path.join(image_folder, filename)
        image2_path = "idcard.jpg"
        image  = process_image(image1_path,image2_path)
        output_path = os.path.join(output_folder, f"ID_Card_{filename}")
        cv2.imwrite(output_path, image)
